# %%
from model.llm import DMetaLLM
from core.vector_database.jina_clip_wrapper import JinaClipWrapper
from utility.tools import load_images_from_folder

texts = ['A pig', 'A red cat', "A red pig", "This is a flowchat"]
images = load_images_from_folder('../model/image_dataset')
query = "在 RAG 中recall 回 contexts 下一步应该做啥？"

jina_clip_wrapper = JinaClipWrapper(texts, images)
contexts = jina_clip_wrapper.search_for_multimodal(query)
print(contexts)
llm = DMetaLLM()
res = llm.get_multimodal_response(query, contexts)
print(res)

# %%
from model.llm import DMetaLLM
from core.vector_database.jina_clip_wrapper import JinaClipWrapper
from utility.tools import load_images_from_folder

texts = ['A pig', 'A red cat', "A red pig", "This is a flowchat"]
images = load_images_from_folder('../model/image_dataset')
query = "在 RAG 中recall 回 contexts 下一步应该做啥？"

jina_clip_wrapper = JinaClipWrapper(texts, images)
contexts = jina_clip_wrapper.search_for_multimodal(query)
print(contexts)
llm = DMetaLLM()
res = llm.get_multimodal_response(query, contexts)
print(res)

# %%
from model.llm import DMetaLLM
from core.vector_database.jina_clip_wrapper import JinaClipWrapper
from utility.tools import load_images_from_folder

texts = ['A pig', 'A red cat', "A red pig", "This is a flowchat"]
images = load_images_from_folder('../model/image_dataset')
query = "在 RAG 中recall 回 contexts 下一步应该做啥？"

jina_clip_wrapper = JinaClipWrapper(texts, images)
contexts = jina_clip_wrapper.search_for_multimodal(query)
print(contexts)
llm = DMetaLLM()
res = llm.get_multimodal_response(query, contexts)
print(res)

# %%
from model.llm import DMetaLLM
from core.vector_database.jina_clip_wrapper import JinaClipWrapper
from utility.tools import load_images_from_folder

texts = ['A pig', 'A red cat', "A red pig", "This is a flowchat"]
images = load_images_from_folder('../model/image_dataset')
query = "在 RAG 中recall 回 contexts 下一步应该做啥？"

jina_clip_wrapper = JinaClipWrapper(texts, images)
contexts = jina_clip_wrapper.search_for_multimodal(query)
print(contexts)
llm = DMetaLLM()
res = llm.get_multimodal_response(query, contexts)
print(res)

# %%
from model.llm import DMetaLLM
from core.vector_database.jina_clip_wrapper import JinaClipWrapper
from utility.tools import load_images_from_folder

texts = ['A pig', 'A red cat', "A red pig", "This is a flowchat"]
images = load_images_from_folder('../model/image_dataset')
query = "在 RAG 中recall 回 contexts 下一步应该做啥？"

jina_clip_wrapper = JinaClipWrapper(texts, images)
contexts = jina_clip_wrapper.search_for_multimodal(query)
print(contexts)
llm = DMetaLLM()
res = llm.get_multimodal_response(query, contexts)
print(res)

# %%
from model.llm import DMetaLLM
from core.vector_database.jina_clip_wrapper import JinaClipWrapper
from utility.tools import load_images_from_folder

texts = ['A pig', 'A red cat', "A red pig", "This is a flowchat"]
images = load_images_from_folder('../model/image_dataset')
query = "在 RAG 中recall 回 contexts 下一步应该做啥？"

jina_clip_wrapper = JinaClipWrapper(texts, images)
contexts = jina_clip_wrapper.search_for_multimodal(query)
print(contexts)
llm = DMetaLLM()
res = llm.get_multimodal_response(query, contexts)
print(res)

# %%
from model.llm import DMetaLLM
from core.vector_database.jina_clip_wrapper import JinaClipWrapper
from utility.tools import load_images_from_folder

texts = ['A pig', 'A red cat', "A red pig", "This is a flowchat"]
images = load_images_from_folder('../model/image_dataset')
query = "在 RAG 中recall 回 contexts 下一步应该做啥？"

jina_clip_wrapper = JinaClipWrapper(texts, images)
contexts = jina_clip_wrapper.search_for_multimodal(query)
print(contexts)
llm = DMetaLLM()
res = llm.get_multimodal_response(query, contexts)
print(res)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from model.llm import DMetaLLM
#       2 from core.vector_database.jina_clip_wrapper import JinaClipWrapper
#       3 from utility.tools import load_images_from_folder
#
# File _pydevd_bundle/pydevd_cython_darwin_311_64.pyx:1187, in _pydevd_bundle.pydevd_cython_darwin_311_64.SafeCallWrapper.__call__()
#
# File _pydevd_bundle/pydevd_cython_darwin_311_64.pyx:627, in _pydevd_bundle.pydevd_cython_darwin_311_64.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle/pydevd_cython_darwin_311_64.pyx:1103, in _pydevd_bundle.pydevd_cython_darwin_311_64.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle/pydevd_cython_darwin_311_64.pyx:1061, in _pydevd_bundle.pydevd_cython_darwin_311_64.PyDBFrame.trace_dispatch()
#
# File /Applications/PyCharm.app/Contents/plugins/python/helpers-pro/jupyter_debug/pydev_jupyter_plugin.py:169, in stop(plugin, pydb, frame, event, args, stop_info, arg, step_cmd)
#     167     frame = suspend_jupyter(main_debugger, thread, frame, step_cmd)
#     168     if frame:
# --> 169         main_debugger.do_wait_suspend(thread, frame, event, arg)
#     170         return True
#     171 return False
#
# File /Applications/PyCharm.app/Contents/plugins/python/helpers/pydev/pydevd.py:1201, in PyDB.do_wait_suspend(self, thread, frame, event, arg, send_suspend_message, is_unhandled_exception)
#    1198         from_this_thread.append(frame_id)
#    1200 with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, stop_reason):
# -> 1201     self._do_wait_suspend(thread, frame, event, arg, suspend_type, from_this_thread)
#
# File /Applications/PyCharm.app/Contents/plugins/python/helpers/pydev/pydevd.py:1216, in PyDB._do_wait_suspend(self, thread, frame, event, arg, suspend_type, from_this_thread)
#    1213             self._call_mpl_hook()
#    1215         self.process_internal_commands()
# -> 1216         time.sleep(0.01)
#    1218 self.cancel_async_evaluation(get_current_thread_id(thread), str(id(frame)))
#    1220 # process any stepping instructions
#
# KeyboardInterrupt:
